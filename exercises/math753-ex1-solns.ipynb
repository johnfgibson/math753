# %% [markdown]
# # Gauss-Newton example: cell phone triangularization
#
# ### Step 1:
#
# Write a Julia function `gaussNewton` that computes the least-squares solution $x$ to the overdetermined nonlinear equation $f(x) = 0$ using using Gauss-Newton iteration. You can choose between two different approaches, based on different sets of arguments
#
#   * `gaussNewton(f, x)` which estimates the matrix of partial derivatives via finite differencing, or
#   * `gaussNewton(f, x, Df)` which computes the matrix of partial derivatives from a user-supplied function `Df(x)`.

# %%
function gaussnewton(f, Df, x₀) 
    
    x = copy(x₀)
    
    for n=1:10
        Dfx = Df(x)
        Δx = -(Dfx'*Dfx)\(Dfx'*f(x))
        x = x + Δx
    end
    
    return x
end
# Out:
# gaussnewton (generic function with 1 method)

# %% [markdown]
# ### Step 2:
#
# Let $(a_i, b_i)$ be a list of positions of cell phone towers in the $x,y$ plane,
# and let $r_i$ be the list of distances from each tower to your phone at the unknown point $(x,y)$ (measured approximately by the transmission times of signals).
#
# \begin{equation*}
# r_i^2 = (x - a_i)^2 + (y - b_i)^2
# \end{equation*}
#
# Translate this system of equations into a vector-valued function of the form $f(x) = 0$, where $x$ is a vector $x=(x_1, x_2)$ instead of the previous variables $(x,y)$.

# %%
# Put vector a and b in a matrix c, letting c[i,1] = a[i] and c[i,2] = b[i]
# This allows a simplified expression of ∂fᵢ/∂xⱼ

# fᵢ(x)  = (x₁ - cᵢ₁)² + (x₂ - cᵢ₂)² - rᵢ²

# ∂fᵢ/∂xⱼ = 2(xⱼ - cᵢⱼ)

# %% [markdown]
# ### Step 3:
#
# Test your Gauss-Newton code on a simple problem whose solution is straightforward. A good simple problem is to put the cell phone towers at the corners of a square: (1,1), (1,3), (3,1), and (3,3), and the cell phone user at the center of the square (2,2). The cell phone user is than equiditant from each tower, with distance $\sqrt{2} \approx 1.414$. But due to some noise or innaccuracy, the distances to those four towers are measured as $r = (1.41, 1.45, 1.43, 1.42)$, respectively.
#
# Write a Julia function `f(x)` that instantiates your $f(x)$ function from step 2 with the appropriate constants filled in. A really good solution will put the cell phone tower locations in two vectors `a` and `b`, the distances in a vector `r`, and then construct the function `f(x)` from `a,b,r` in a single line of Julia code.

# %%
c = [1 1; 1 3; 3 1; 3 3]; r = [1.41; 1.45; 1.43; 1.42]

f(x) = [(x[1] - c[i,1])^2 + (x[2] - c[i,2])^2 - r[i]^2 for i in 1:length(r)]

Df(x) = [2*(x[j]-c[i,j]) for i in 1:size(c,1), j in 1:2]

x₀ = [2; 2]

x = gaussnewton(f,Df, x₀)
# Out:
# 2-element Array{Float64,1}:
#  2.00373
#  1.98906

# %% [markdown]
# ### Step 4:
#
# Now try your Gauss-Newton code on a problem with unknown solution. Your phone measures distances (5, 3.6, 4.1, 6) to cell towers at (1,1), (0,3), (4,2), and (8,8). Where are you?

# %%
c = [1 1; 0 3; 4 2; 8 8]; r = [5; 3.6; 4.1; 6]

f(x) = [(x[1] - c[i,1])^2 + (x[2] - c[i,2])^2 - r[i]^2 for i in 1:length(r)]

Df(x) = [2*(x[j]-c[i,j]) for i in 1:size(c,1), j in 1:2]

x₀ = [2; 2]

x = gaussnewton(f,Df, x₀)
# Out:
# 2-element Array{Float64,1}:
#  2.41027
#  5.77536

# %% [markdown]
# ### Step 5:
#
# Make a plot for the above problem, showing the cell phone towers as dots with circles around them of the right radii, and your answer from 4 with another symbol. Is the solution computed from step 4 located close to where all the circles nearly intersect?

# %%
using Plots; gr()
θ = linspace(0,2π)

scatter(c[:,1], c[:,2], marker=:circ, color="red", label="towers")
for i in 1:size(c,1)
    plot!(c[i,1] + r[i]*cos.(θ), c[i,2] + r[i]*sin.(θ), color="red", label="radii")
end
scatter!([x[1]], [x[2]], marker=:circ, color="blue", label="phone", xlim=(-1,11), ylim=(0,8))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0100)" points="
# 22.3377,375.813 580.315,375.813 580.315,11.811 22.3377,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="22" y="11" width="559" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   68.8358,370.353 68.8358,17.2711
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   185.081,370.353 185.081,17.2711
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   301.326,370.353 301.326,17.2711
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   417.572,370.353 417.572,17.2711
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   533.817,370.353 533.817,17.2711
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   30.7073,375.813 571.945,375.813
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   30.7073,284.813 571.945,284.813
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   30.7073,193.812 571.945,193.812
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   30.7073,102.812 571.945,102.812
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   30.7073,11.811 571.945,11.811
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,375.813 22.3377,11.811
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   68.8358,375.813 68.8358,370.353
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   185.081,375.813 185.081,370.353
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   301.326,375.813 301.326,370.353
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   417.572,375.813 417.572,370.353
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   533.817,375.813 533.817,370.353
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,375.813 30.7073,375.813
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,284.813 30.7073,284.813
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,193.812 30.7073,193.812
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,102.812 30.7073,102.812
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   22.3377,11.811 30.7073,11.811
#   "/>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 68.8358, 389.613)" x="68.8358" y="389.613">0.0</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 185.081, 389.613)" x="185.081" y="389.613">2.5</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 301.326, 389.613)" x="301.326" y="389.613">5.0</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 417.572, 389.613)" x="417.572" y="389.613">7.5</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 533.817, 389.613)" x="533.817" y="389.613">10.0</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.3377, 380.313)" x="16.3377" y="380.313">0</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.3377, 289.313)" x="16.3377" y="289.313">2</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.3377, 198.312)" x="16.3377" y="198.312">4</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.3377, 107.312)" x="16.3377" y="107.312">6</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 16.3377, 16.311)" x="16.3377" y="16.311">8</text>
# </g>
# <circle clip-path="url(#clip0102)" style="fill:#000000; stroke:none; fill-opacity:1" cx="115.334" cy="330.313" r="4"/>
# <circle clip-path="url(#clip0102)" style="fill:#ff0000; stroke:none; fill-opacity:1" cx="115.334" cy="330.313" r="3"/>
# <circle clip-path="url(#clip0102)" style="fill:#000000; stroke:none; fill-opacity:1" cx="68.8358" cy="239.313" r="4"/>
# <circle clip-path="url(#clip0102)" style="fill:#ff0000; stroke:none; fill-opacity:1" cx="68.8358" cy="239.313" r="3"/>
# <circle clip-path="url(#clip0102)" style="fill:#000000; stroke:none; fill-opacity:1" cx="254.828" cy="284.813" r="4"/>
# <circle clip-path="url(#clip0102)" style="fill:#ff0000; stroke:none; fill-opacity:1" cx="254.828" cy="284.813" r="3"/>
# <circle clip-path="url(#clip0102)" style="fill:#000000; stroke:none; fill-opacity:1" cx="440.821" cy="11.811" r="4"/>
# <circle clip-path="url(#clip0102)" style="fill:#ff0000; stroke:none; fill-opacity:1" cx="440.821" cy="11.811" r="3"/>
# <polyline clip-path="url(#clip0102)" style="stroke:#ff0000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   347.824,330.313 345.916,301.221
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#ff0000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   345.916,301.221 340.221,272.606
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#ff0000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   340.221,272.606 330.833,244.

# %% [markdown]
# Yes, Gauss-Newton determined the phone location at the near-intersection of all the circles!
