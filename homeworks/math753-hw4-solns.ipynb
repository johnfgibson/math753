# %% [markdown]
# # Solutions to Math 753/853 HW4 Polynomial Interpolation

# %% [markdown]
# ## Problem 1
#
# **(a)** Write a function `polyeval(c,x)` that implements Horner's method for polynomial interpolation without base points. I.e. given a vector of monomial coefficients $c$ you want to evaluate the polynomial
#
# \begin{equation*}
# P(x) = \sum_{n=0}^{m-1} c_n x^n
# \end{equation*}
#
# using Horner's method of nested multiplication. E.g. write the function so that it evaluates the polynomial
#
# \begin{equation*}
# P(x) = c_0 + c_1 x + c_2 x^2 + c_3 x^3 + c_4 x^4
# \end{equation*}
#
# with this series of multiplications and additions
#
# \begin{equation*}
# P(x) = c_0 + x \, [c_1 + x \, [c_2 + x \, [c_3 + x \, c_4]]]
# \end{equation*}
#
# Your function should have inputs $c$ and $x$, and it should return $P(x)$. Make sure the function works when $x$ is a vector, returning a vector of values $P(x)$. Your function should also work equally well on all numerical types.
#
# **Warning:** Note that the natural mathematical expressions for polynomials have indices that start at 0, but that
# Julia and many other programming languages use indices that start at 1. You'll have to negotiate this difference when writing your Horner evaluation function

# %%
function polyeval(c,x)
    N = length(c);
    p = c[N]
    for n = N-1:-1:1
        y = c[n] + x.*p
    end
    p
end
# Out:
# polyeval (generic function with 1 method)

# %% [markdown]
# **(b)** Test your `polyeval(c,x)` function on a simple quadratic or cubic polynomial of your choice. Do this by constructing a simple polynomial function in Julia, e.g. $f(x) = 1 + 2x - 3x^2$, plotting a few points `(x, f(x))` with dots, and then plotting the same polynomial as a smooth line using your `polyeval` function with inputs `c=[1 2 -3]` and an `x` vector created with `linspace`. Label the axes and add a legend that shows which symbol is for the datapoints and which is for `polyeval`.

# %%
f(x) = 1 + 2x - 3x^2
xdata = [0, 1, 2]

using Plots; gr()
scatter(xdata, f.(xdata), marker=:circ, color="red", label="sample points")
x=linspace(-0.5, 2.5)
plot!(x, polyeval([1,2,-3], x), linestyle=:solid, color="blue", label="polyeval")
plot!(xlabel="x", ylabel="y", title="test of horner method code")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5500)" points="
# 51.5968,360.065 580.315,360.065 580.315,31.4961 51.5968,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="51" y="31" width="530" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   66.5605,355.137 66.5605,36.4246
#   "/>
# <polyline clip-path="url(#clip5502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   149.692,355.137 149.692,36.4246
#   "/>
# <polyline clip-path="url(#clip5502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   232.824,355.137 232.824,36.4246
#   "/>
# <polyline clip-path="url(#clip5502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   315.956,355.137 315.956,36.4246
#   "/>
# <polyline clip-path="url(#clip5502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   399.088,355.137 399.088,36.4246
#   "/>
# <polyline clip-path="url(#clip5502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   482.219,355.137 482.219,36.4246
#   "/>
# <polyline clip-path="url(#clip5502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   565.351,355.137 565.351,36.4246
#   "/>
# <polyline clip-path="url(#clip5502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,334.257 572.384,334.257
#   "/>
# <polyline clip-path="url(#clip5502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,290.232 572.384,290.232
#   "/>
# <polyline clip-path="url(#clip5502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,246.207 572.384,246.207
#   "/>
# <polyline clip-path="url(#clip5502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,202.182 572.384,202.182
#   "/>
# <polyline clip-path="url(#clip5502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,158.157 572.384,158.157
#   "/>
# <polyline clip-path="url(#clip5502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,114.133 572.384,114.133
#   "/>
# <polyline clip-path="url(#clip5502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,70.1077 572.384,70.1077
#   "/>
# <polyline clip-path="url(#clip5500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip5500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,360.065 51.5968,31.4961
#   "/>
# <polyline clip-path="url(#clip5500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   66.5605,360.065 66.5605,355.137
#   "/>
# <polyline clip-path="url(#clip5500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   149.692,360.065 149.692,355.137
#   "/>
# <polyline clip-path="url(#clip5500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   232.824,360.065 232.824,355.137
#   "/>
# <polyline clip-path="url(#clip5500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   315.956,360.065 315.956,355.137
#   "/>
# <polyline clip-path="url(#clip5500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   399.088,360.065 399.088,355.137
#   "/>
# <polyline clip-path="url(#clip5500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   482.219,360.065 482.219,355.137
#   "/>
# <polyline clip-path="url(#clip5500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   565.351,360.065 565.351,355.137
#   "/>
# <polyline clip-path="url(#clip5500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,334.257 59.5276,334.257
#   "/>
# <polyline clip-path="url(#clip5500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,290.232 59.5276,290.232
#   "/>
# <polyline clip-path="url(#clip5500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,246.207 59.5276,246.207
#   "/>
# <polyline clip-path="url(#clip5500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,202.182 59.5276,202.182
#   "/>
# <polyline clip-path="url(#clip5500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,158.157 59.5276,158.157
#   "/>
# <polyline clip-path="url(#clip5500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,114.133 59.5276,114.133
#   "/>
# <polyline clip-path="url(#clip5500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,70.1077 59.5276,70.1077
#   "/>
# <g clip-path="url(#clip5500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 66.5605, 373.865)" x="66.5605" y="373.865">-0.5</text>
# </g>
# <g clip-path="url(#clip5500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 149.692, 373.865)" x="149.692" y="373.865">0.0</text>
# </g>
# <g clip-path="url(#clip5500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 232.824, 373.865)" x="232.824" y="373.865">0.5</text>
# </g>
# <g clip-path="url(#clip5500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 315.956, 373.865)" x="315.956" y="373.865">1.0</text>
# </g>
# <g clip-path="url(#clip5500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 399.088, 373.865)" x="399.088" y="373.865">1.5</text>
# </g>
# <g clip-path="url(#clip5500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 482.219, 373.865)" x="482.219" y="373.865">2.0</text>
# </g>
# <g clip-path="url(#clip5500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 565.351, 373.865)" x="565.351" y="373.865">2.5</text>
# </g>
# <g clip-path="url(#clip5500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.5968, 338.757)" x="45.5968" y="338.757">-12</text>
# </g>
# <g clip-path="url(#clip5500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.5968, 294.732)" x="45.5968" y="294.732">-10</text>
# </g>
# <g clip-path="url(#clip5500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.5968, 250.707)" x="45.5968" y="250.707">-8</text>
# </g>
# <g clip-path="url(#clip5500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-se

# %% [markdown]
# Yay! It looks like `polyeval` works correctly.

# %% [markdown]
# ## Problem 2
#
# **(a).** Write a function `polyeval(c,b,x)` that implements Horner's method for polynomial interpolation *with*  base points. E.g. given a vector of five coefficients `c` and four base points `b` you want to evaluate the polynomial
#
# \begin{equation*}
# P(x) = c_0 + (x - b_1) \, [c_1 + (x - b_2) [c_2 + (x - b_3) [c_3 + (x - b_4) \, c_4]]]
# \end{equation*}
#
# Your function should have inputs `c`, `b`, and `x`, and as in problem 1(a), it should work on vectors `x` of arbitrary numeric type. Typically the base points $b$ will be the $x$ values $x_1, x_2, \ldots,$ of the datapoints $(x_i, y_i)$ used in a Newton divided difference polynomial fit.

# %%
# Math  indices: P(x) = c0 + (x - b1) [c1 + (x - b2) [c2 + (x - b3) [c3 + (x - b4) c4]]]
# Julia indices: P(x) = c1 + (x - b1) [c2 + (x - b2) [c3 + (x - b3) [c4 + (x - b4) c5]]]

function polyeval(c,b,x)
    N = length(c);
    p = c[N]
    for n = N-1:-1:1
        p = c[n] + (x-b[n]).*p
    end
    p
end
# Out:
# polyeval (generic function with 1 method)

# %% [markdown]
# **(b)** As in problem 1(b), test your `polyeval(c,b,x)` function graphically on the polynomial
# $P(x) = 3 + (x-1)[-2 + (x-2) [1 + (x-3) \, 2]$.

# %%
P(x) = 3 + (x-1)*(-2 + (x-2)*(1 + (x-3)*2))
xdata = [0, 1, 2, 3]

c = [3, -2, 1, 2]
b = [1, 2, 3]
using Plots; gr()
scatter(xdata, P.(xdata), marker=:circ, color="red", label="sample points")
x=linspace(-0.5, 3.5)
plot!(x, polyeval(c,b,x), linestyle=:solid, color="blue", label="polyeval")
plot!(legend=:bottomright, xlabel="x", ylabel="y", title="test of horner code with base points")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5700)" points="
# 51.5968,360.065 580.315,360.065 580.315,31.4961 51.5968,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="51" y="31" width="530" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   128.909,355.137 128.909,36.4246
#   "/>
# <polyline clip-path="url(#clip5702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   253.607,355.137 253.607,36.4246
#   "/>
# <polyline clip-path="url(#clip5702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   378.305,355.137 378.305,36.4246
#   "/>
# <polyline clip-path="url(#clip5702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   503.002,355.137 503.002,36.4246
#   "/>
# <polyline clip-path="url(#clip5702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,329.632 572.384,329.632
#   "/>
# <polyline clip-path="url(#clip5702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,259.184 572.384,259.184
#   "/>
# <polyline clip-path="url(#clip5702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,188.736 572.384,188.736
#   "/>
# <polyline clip-path="url(#clip5702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,118.288 572.384,118.288
#   "/>
# <polyline clip-path="url(#clip5702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,47.84 572.384,47.84
#   "/>
# <polyline clip-path="url(#clip5700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip5700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,360.065 51.5968,31.4961
#   "/>
# <polyline clip-path="url(#clip5700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   128.909,360.065 128.909,355.137
#   "/>
# <polyline clip-path="url(#clip5700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   253.607,360.065 253.607,355.137
#   "/>
# <polyline clip-path="url(#clip5700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   378.305,360.065 378.305,355.137
#   "/>
# <polyline clip-path="url(#clip5700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   503.002,360.065 503.002,355.137
#   "/>
# <polyline clip-path="url(#clip5700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,329.632 59.5276,329.632
#   "/>
# <polyline clip-path="url(#clip5700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,259.184 59.5276,259.184
#   "/>
# <polyline clip-path="url(#clip5700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,188.736 59.5276,188.736
#   "/>
# <polyline clip-path="url(#clip5700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,118.288 59.5276,118.288
#   "/>
# <polyline clip-path="url(#clip5700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,47.84 59.5276,47.84
#   "/>
# <g clip-path="url(#clip5700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 128.909, 373.865)" x="128.909" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip5700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 253.607, 373.865)" x="253.607" y="373.865">1</text>
# </g>
# <g clip-path="url(#clip5700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 378.305, 373.865)" x="378.305" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip5700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 503.002, 373.865)" x="503.002" y="373.865">3</text>
# </g>
# <g clip-path="url(#clip5700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.5968, 334.132)" x="45.5968" y="334.132">-15</text>
# </g>
# <g clip-path="url(#clip5700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.5968, 263.684)" x="45.5968" y="263.684">-10</text>
# </g>
# <g clip-path="url(#clip5700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.5968, 193.236)" x="45.5968" y="193.236">-5</text>
# </g>
# <g clip-path="url(#clip5700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.5968, 122.788)" x="45.5968" y="122.788">0</text>
# </g>
# <g clip-path="url(#clip5700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.5968, 52.34)" x="45.5968" y="52.34">5</text>
# </g>
# <g clip-path="url(#clip5700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 315.956, 18)" x="315.956" y="18">test of horner code with base points</text>
# </g>
# <g clip-path="url(#clip5700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 315.956, 397.6)" x="315.956" y="397.6">x</text>
# </g>
# <g clip-path="url(#clip5700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">y</text>
# </g>
# <circle clip-path="url(#clip5702)" style="fill:#000000; stroke:none; fill-opacity:1" cx="128.909" cy="188.736" r="4"/>
# <circle clip-path="url(#clip5702)" style="fill:#ff0000; stroke:none; fill-opacity:1" cx="128.909" cy="188.736" r="3"/>
# <circle clip-path="url(#clip5702)" style="fill:#000000; stroke:none; fill-opacity:1" cx="253.607" cy="76.0192" r="4"/>
# <circle clip-path="url(#clip5702)" style="fill:#ff0000; stroke:none; fill-opacity:1" cx="253.607" cy="76.0192" r="3"/>
# <circle clip-path="url(#clip5702)" style="fill:#000000; stroke:none; fill-opacity:1" cx="378.305" cy="104.198" r="4"/>
# <circle clip-path="url(#clip5702)" style="fill:#ff0000; stroke:none; fill-opacity:1" cx="378.305" cy="104.198" r="3"/>
# <circle clip-path="url(#clip5702)" style="fill:#000000; stroke:none; fill-opacity:1" cx="503.002" cy="104.198" r="4"/>
# <circle clip-path="url(#clip5702)" style="fill:#ff0000; stroke:none; fill-opacity:1" cx="503.002" cy="104.198" r="3"/>
# <polyline clip-path="url(#clip5702)" style="stroke:#0000ff; stroke-width:1; stroke-opacity:1; fill:none" points="
#   66.5605,350.766 76.7399,318.135
#   "/>
# <polyline clip-path="url(#clip5702)" style="stroke:#0000ff; stroke-width:1; stroke-opacity:1; fill:none" points="
#   76.

# %% [markdown]
# # Problem 3
#
# **(a)** To familiarize yourself with the Newton Divided Differences algorithm, work out on paper (or in text/markdown in this notebook) the cubic interpolating polynomial for the $(x,y)$ data points $(-2,8), (0, 4), (1,2), (3,-3)$.

# %%
#  xᵢ | yᵢ 
# -------------------------
# -2 |  8
#    |     -4/2 = -2
#  0 |  4               0/3 = 0    
#    |     -2/1 = -2                     (-1/6)/5 = -1/30  
#  1 |  2               (-9/2)/3 = -1/6          
#    |     -5/2 = -5/2  
#  3 | -3
#
# P(x) = 8 + (x+2)(-2 + (x-0)*(0 + (x-1)*(0/10)))

# %% [markdown]
# **(b)** Make a plot that verifies your interpolating polynomial graphically, showing the data points as dots and the interpolant as a smooth curve.

# %%
using Plots; gr()
xdata = [-2, 0, 1, 3]
ydata = [8, 4, 2, -3]

P(x) = 8 + (x+2)*(-2 + (x-0)*(0 + (x-1)*(-1//30)))

x = linspace(-3,4)
scatter(xdata, ydata, marker=:circ, color="green", label="data")
plot!(x, P.(x), linestyle=:solid, color="purple", label="poly interpolant")
plot!(xlabel="x", ylabel="y", title="testing newton divided differences by hand")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0700)" points="
# 45.0072,360.065 580.315,360.065 580.315,31.4961 45.0072,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="45" y="31" width="536" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   132.301,355.137 132.301,36.4246
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   276.589,355.137 276.589,36.4246
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   420.877,355.137 420.877,36.4246
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   565.165,355.137 565.165,36.4246
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,324.935 572.285,324.935
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,232.682 572.285,232.682
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,140.429 572.285,140.429
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,48.1755 572.285,48.1755
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,360.065 45.0072,31.4961
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   132.301,360.065 132.301,355.137
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   276.589,360.065 276.589,355.137
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   420.877,360.065 420.877,355.137
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   565.165,360.065 565.165,355.137
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,324.935 53.0368,324.935
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,232.682 53.0368,232.682
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,140.429 53.0368,140.429
#   "/>
# <polyline clip-path="url(#clip0700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,48.1755 53.0368,48.1755
#   "/>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 132.301, 373.865)" x="132.301" y="373.865">-2</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 276.589, 373.865)" x="276.589" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 420.877, 373.865)" x="420.877" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 565.165, 373.865)" x="565.165" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 329.435)" x="39.0072" y="329.435">-5</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 237.182)" x="39.0072" y="237.182">0</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 144.929)" x="39.0072" y="144.929">5</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 52.6755)" x="39.0072" y="52.6755">10</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 312.661, 18)" x="312.661" y="18">testing newton divided differences by hand</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 312.661, 397.6)" x="312.661" y="397.6">x</text>
# </g>
# <g clip-path="url(#clip0700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">y</text>
# </g>
# <circle clip-path="url(#clip0702)" style="fill:#000000; stroke:none; fill-opacity:1" cx="132.301" cy="85.0768" r="4"/>
# <circle clip-path="url(#clip0702)" style="fill:#008000; stroke:none; fill-opacity:1" cx="132.301" cy="85.0768" r="3"/>
# <circle clip-path="url(#clip0702)" style="fill:#000000; stroke:none; fill-opacity:1" cx="276.589" cy="158.879" r="4"/>
# <circle clip-path="url(#clip0702)" style="fill:#008000; stroke:none; fill-opacity:1" cx="276.589" cy="158.879" r="3"/>
# <circle clip-path="url(#clip0702)" style="fill:#000000; stroke:none; fill-opacity:1" cx="348.733" cy="195.781" r="4"/>
# <circle clip-path="url(#clip0702)" style="fill:#008000; stroke:none; fill-opacity:1" cx="348.733" cy="195.781" r="3"/>
# <circle clip-path="url(#clip0702)" style="fill:#000000; stroke:none; fill-opacity:1" cx="493.021" cy="288.034" r="4"/>
# <circle clip-path="url(#clip0702)" style="fill:#008000; stroke:none; fill-opacity:1" cx="493.021" cy="288.034" r="3"/>
# <polyline clip-path="url(#clip0702)" style="stroke:#800080; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.1574,40.7952 70.4637,47.6375
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#800080; stroke-width:1; stroke-opacity:1; fill:none" points="
#   70.4637,47.6375 80.7699,54.2898
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#800080; stroke-width:1; stroke-opacity:1; fill:none" points="
#   80.7699,54.2898 91.0762,60.7628
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#800080; stroke-width:1; stroke-opacity:1; fill:none" points="
#   91.0762,60.7628 101.382,67.0672
#   "/>
# <polyline clip-path="url(#clip0702)" style="stroke:#800080; stroke-width:1; stroke-opacity:1; fill:none" points="
#   101.382,67.0672 111.689,73.2138
#   "/>
# <polyline clip-path="url(#clip0702)"

# %% [markdown]
# # Problem 4
#
# **(a)** Write a function ``newtondivdiff(x,y)`` that returns `(c,b)`, the polynomial coefficients `c` and the base points `b` for the polynomial interpolant that passes through the data points $(x_1, y_1), (x_2, y_2), \dots, (x_m, y_m)$. The return values $c$ and $b$ should be arranged to pass directly into your `polyeval(c,b)` function from problem 2.

# %%
function newtondivdiff(x,y)
    N = length(x);    
    if length(y) ≠ N
        println("newtondivdiff(x,y) error: length(x) ≠ length(y)")
        return zeros(x)
    end

    F = zeros(N,N) # matrix to store divided differences
    F[:,1] = y
    
    for j=2:N
        for i=1:N+1-j
            F[i,j] = (F[i+1,j-1]-F[i,j-1])/(x[i+j-1]-x[i])
        end
    end
    c = F[1,:]
    b = x
    (c, b)
end
# Out:
# newtondivdiff (generic function with 1 method)

# %% [markdown]
# **(b)** Test your ``newtondivdiff(x,y)`` function with this series of steps
#
#   1. construct a quadratic or cubic polynomial, e.g. $f(x) = 1 + 2x - 3x^2$
#   2. construct a vector `xdata` with three values for a quadratic, or four for a cubic, e.g. `xdata = [-2 -1 1]`.
#   3. evaluate $f$ at `xdata` to get a vector of $y$ values `ydata`
#   4. compute the coefficients `c` and basepoints `b` of the polynomial interpolant using `newtondivdiff(xdata, ydata)`
#   5. evaluate your polynomial interpolant on a large number of $x$ points, e.g. `x = linspace(-2, 2); y = polyeval(c,b,x)`
#   6. make a plot showing the datapoints `xdata, ydata` with dots and the smooth curve `x,y` with a line.
#   7. label the axes and provide a legend

# %%
f(x) = 1 + 2x - 3x^2
xdata = [-2, -1, 1]
ydata = f.(xdata)

(c,b) = newtondivdiff(xdata, ydata)
x = linspace(-2,2)
y = polyeval(c,b,x)

scatter(xdata, ydata, marker=:circ, color="green", label="data")
plot!(x, y, linestyle=:solid, color="purple", label="poly interpolant")
plot!(xlabel="x", ylabel="y", title="testing Newton divided differences algorithm")
plot!(legend=:bottomright)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1100)" points="
# 51.5968,360.065 580.315,360.065 580.315,31.4961 51.5968,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="51" y="31" width="530" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   66.5605,355.137 66.5605,36.4246
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   191.258,355.137 191.258,36.4246
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   315.956,355.137 315.956,36.4246
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   440.654,355.137 440.654,36.4246
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   565.351,355.137 565.351,36.4246
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,350.766 572.384,350.766
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,255.857 572.384,255.857
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,160.948 572.384,160.948
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,66.0385 572.384,66.0385
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,360.065 51.5968,31.4961
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   66.5605,360.065 66.5605,355.137
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   191.258,360.065 191.258,355.137
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   315.956,360.065 315.956,355.137
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   440.654,360.065 440.654,355.137
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   565.351,360.065 565.351,355.137
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,350.766 59.5276,350.766
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,255.857 59.5276,255.857
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,160.948 59.5276,160.948
#   "/>
# <polyline clip-path="url(#clip1100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,66.0385 59.5276,66.0385
#   "/>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 66.5605, 373.865)" x="66.5605" y="373.865">-2</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 191.258, 373.865)" x="191.258" y="373.865">-1</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 315.956, 373.865)" x="315.956" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 440.654, 373.865)" x="440.654" y="373.865">1</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 565.351, 373.865)" x="565.351" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.5968, 355.266)" x="45.5968" y="355.266">-15</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.5968, 260.357)" x="45.5968" y="260.357">-10</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.5968, 165.448)" x="45.5968" y="165.448">-5</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.5968, 70.5385)" x="45.5968" y="70.5385">0</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 315.956, 18)" x="315.956" y="18">testing Newton divided differences algorithm</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 315.956, 397.6)" x="315.956" y="397.6">x</text>
# </g>
# <g clip-path="url(#clip1100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">y</text>
# </g>
# <circle clip-path="url(#clip1102)" style="fill:#000000; stroke:none; fill-opacity:1" cx="66.5605" cy="350.766" r="4"/>
# <circle clip-path="url(#clip1102)" style="fill:#008000; stroke:none; fill-opacity:1" cx="66.5605" cy="350.766" r="3"/>
# <circle clip-path="url(#clip1102)" style="fill:#000000; stroke:none; fill-opacity:1" cx="191.258" cy="141.966" r="4"/>
# <circle clip-path="url(#clip1102)" style="fill:#008000; stroke:none; fill-opacity:1" cx="191.258" cy="141.966" r="3"/>
# <circle clip-path="url(#clip1102)" style="fill:#000000; stroke:none; fill-opacity:1" cx="440.654" cy="66.0385" r="4"/>
# <circle clip-path="url(#clip1102)" style="fill:#008000; stroke:none; fill-opacity:1" cx="440.654" cy="66.0385" r="3"/>
# <polyline clip-path="url(#clip1102)" style="stroke:#800080; stroke-width:1; stroke-opacity:1; fill:none" points="
#   66.5605,350.766 76.7399,329.452
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#800080; stroke-width:1; stroke-opacity:1; fill:none" points="
#   76.7399,329.452 86.9193,308.897
#   "/>
# <polyline clip-path="url(#clip1102)" style="stroke:#800080; stroke-width:1; stroke-opacity:1; fill:none" points="
#   86.9193,308.897 97.0987,289.101
#   "/>
# <polyline clip-path="u

# %% [markdown]
# ## Problem 5

# %% [markdown]
# The expected lifetime of an industrial fan decreases with operating temperature, according to the experimental data in this table
#
# \begin{array}{c|c}
# temp~F & weeks \\
# 77 & 57 \\
# 104 & 45 \\
# 122 & 38 \\
# 140 & 32
# \end{array}
#
# Estimate the expected fan lifetime at 130 degrees Farenheit using polynomial interpolation. Make a plot showing the datapoints with dots and the interpolant as a smooth curve over temperatures between 50F and 150F.

# %%
tempdata = [77, 104, 122, 140]
lifedata = [57, 45, 38, 32]
(c,b) = newtondivdiff(tempdata, lifedata)

scatter(tempdata, lifedata, marker=:circ, color="orange", label="data")

t = linspace(50,150)
plot!(t, polyeval(c,b,t), linestyle=:solid, color="magenta", label="poly interpolant")
plot!(xlabel="temperature, F", ylabel="lifetime, weeks", title="lifetime of industrial fan")
plot!(legend=:topright)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1700)" points="
# 44.6753,360.065 580.315,360.065 580.315,31.4961 44.6753,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="44" y="31" width="537" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   110.367,355.137 110.367,36.4246
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   211.431,355.137 211.431,36.4246
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   312.495,355.137 312.495,36.4246
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   413.559,355.137 413.559,36.4246
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   514.623,355.137 514.623,36.4246
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.7099,344.449 572.28,344.449
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.7099,269.074 572.28,269.074
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.7099,193.699 572.28,193.699
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.7099,118.324 572.28,118.324
#   "/>
# <polyline clip-path="url(#clip1702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.7099,42.9488 572.28,42.9488
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,360.065 44.6753,31.4961
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   110.367,360.065 110.367,355.137
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   211.431,360.065 211.431,355.137
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   312.495,360.065 312.495,355.137
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   413.559,360.065 413.559,355.137
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   514.623,360.065 514.623,355.137
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,344.449 52.7099,344.449
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,269.074 52.7099,269.074
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,193.699 52.7099,193.699
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,118.324 52.7099,118.324
#   "/>
# <polyline clip-path="url(#clip1700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,42.9488 52.7099,42.9488
#   "/>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 110.367, 373.865)" x="110.367" y="373.865">60</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 211.431, 373.865)" x="211.431" y="373.865">80</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 312.495, 373.865)" x="312.495" y="373.865">100</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 413.559, 373.865)" x="413.559" y="373.865">120</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 514.623, 373.865)" x="514.623" y="373.865">140</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 348.949)" x="38.6753" y="348.949">30</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 273.574)" x="38.6753" y="273.574">40</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 198.199)" x="38.6753" y="198.199">50</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 122.824)" x="38.6753" y="122.824">60</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 47.4488)" x="38.6753" y="47.4488">70</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 312.495, 18)" x="312.495" y="18">lifetime of industrial fan</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 312.495, 397.6)" x="312.495" y="397.6">temperature, F</text>
# </g>
# <g clip-path="url(#clip1700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">lifetime, weeks</text>
# </g>
# <circle clip-path="url(#clip1702)" style="fill:#000000; stroke:none; fill-opacity:1" cx="196.271" cy="140.936" r="4"/>
# <circle clip-path="url(#clip1702)" style="fill:#ffa500; stroke:none; fill-opacity:1" cx="196.271" cy="140.936" r="3"/>
# <circle clip-path="url(#clip1702)" style="fill:#000000; stroke:none; fill-opacity:1" cx="332.708" cy="231.386" r="4"/>
# <circle clip-path="url(#clip1702)" style="fill:#ffa500; stroke:none; fill-opacity:1" cx="332.708" cy="231.386" r="3"/>
# <circle clip-path="url(#clip1702)" style="fill:#000000; stroke:none; fill-opacity:1" cx="423.666" cy="284.149" r="4"/>
# <circle clip-path="url(#clip1702)" style="f

# %%
# estimate fan lifetime at 130 F. Answer will be in weeks
t = 130
println("Estimated fan lifetime at $(t) F is $(polyeval(c,b,130)) weeks")
# Out:
# Estimated fan lifetime at 130 F is 35.19968645894572 weeks

# %% [markdown]
# ## Problem 6
#
# **(a)** Given these estimates of world human population over the last fifty years
#
# \begin{array}{c|l}
# year & population~(billions) \\
# 1960 & 3.026 \\
# 1970 & 3.691 \\
# 1980 & 4.449 \\
# 1990 & 5.321 \\
# 2000 & 6.128 \\
# 2010 & 6.916
# \end{array}
#
# estimate the world population in 2025 by extrapolating the polynomial interpolant.

# %%
yeardata  = [1960, 1970, 1980,  1990, 2000, 2010]
popudata  = [3.026, 3.691, 4.449, 5.321, 6.128, 6.916]
(c1,b1) = newtondivdiff(yeardata, popudata)

println("Using data up to 2010, the estimated world population in 2025 is $(polyeval(c1,b1,2025)) billion.")
# Out:
# Using data up to 2010, the estimated world population in 2025 is 9.86719921874999 billion.

# %% [markdown]
# **(b)** Add the current estimated world population of 7.404 billion in 2016 to the data set and give a revised estimate of 2025 population.

# %%
yeardata  = [1960, 1970, 1980,  1990, 2000, 2010, 2016]
popudata  = [3.026, 3.691, 4.449, 5.321, 6.128, 6.916, 7.404]
(c2,b2) = newtondivdiff(yeardata, popudata)

println("Using data up to 2016, the estimated world population in 2025 is $(polyeval(c1,b1,2025)) billion.")
# Out:
# Using data up to 2016, the estimated world population in 2025 is 9.86719921874999 billion.

# %% [markdown]
# **(c)** Make a plot showing the datapoints and the two polynomial interpolants over the range 1950 to 2030. Plot the  interpolant without the 2016 data in blue and with the 2016 data in red.

# %%
scatter(yeardata, popudata, marker=:circ, color="red", label="data")
t = linspace(1950,2030)
plot!(t, polyeval(c1,b1,t), linestyle=:solid, color="green", label="using data to 2010")
plot!(t, polyeval(c2,b2,t), linestyle=:solid, color="blue", label="using data to 2016")
plot!(xlabel="year", ylabel="world population, billions")
plot!(legend=:topleft)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2300)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2300)" points="
# 54.5598,360.065 580.315,360.065 580.315,11.811 54.5598,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="54" y="11" width="527" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   131.439,354.842 131.439,17.0348
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   255.438,354.842 255.438,17.0348
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   379.437,354.842 379.437,17.0348
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   503.436,354.842 503.436,17.0348
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4461,309.292 572.429,309.292
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4461,235.874 572.429,235.874
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4461,162.455 572.429,162.455
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4461,89.0363 572.429,89.0363
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4461,15.6176 572.429,15.6176
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,360.065 54.5598,11.811
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   131.439,360.065 131.439,354.842
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   255.438,360.065 255.438,354.842
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   379.437,360.065 379.437,354.842
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   503.436,360.065 503.436,354.842
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,309.292 62.4461,309.292
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,235.874 62.4461,235.874
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,162.455 62.4461,162.455
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,89.0363 62.4461,89.0363
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,15.6176 62.4461,15.6176
#   "/>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 131.439, 373.865)" x="131.439" y="373.865">1960</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 255.438, 373.865)" x="255.438" y="373.865">1980</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 379.437, 373.865)" x="379.437" y="373.865">2000</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 503.436, 373.865)" x="503.436" y="373.865">2020</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598, 313.792)" x="48.5598" y="313.792">2.5</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598, 240.374)" x="48.5598" y="240.374">5.0</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598, 166.955)" x="48.5598" y="166.955">7.5</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598, 93.5363)" x="48.5598" y="93.5363">10.0</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598, 20.1176)" x="48.5598" y="20.1176">12.5</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 317.437, 397.6)" x="317.437" y="397.6">year</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 185.938)" x="14.4" y="185.938">world population, billions</text>
# </g>
# <circle clip-path="url(#clip2302)" style="fill:#000000; stroke:none; fill-opacity:1" cx="131.439" cy="293.845" r="4"/>
# <circle clip-path="url(#clip2302)" style="fill:#ff0000; stroke:none; fill-opacity:1" cx="131.439" cy="293.845" r="3"/>
# <circle clip-path="url(#clip2302)" style="fill:#000000; stroke:none; fill-opacity:1" cx="193.438" cy="274.316" r="4"/>
# <circle clip-path="url(#clip2302)" style="fill:#ff0000; stroke:none; fill-opacity:1" cx="193.438" cy="274.316" r="3"/>
# <circle clip-path="url(#clip2302)" style="fill:#000000; stroke:none; fill-opacity:1" cx="255.438" cy="252.055" r="4"/>
# <circle clip-path="url(#clip2302)" style="fill:#ff0000; stroke:none; fill-opacity:1" cx="255.438" cy="252.055" r="3"/>
# <circle clip-path="url(#clip2302)" style="fill:#000000; stroke:none; fill-opacity:1" cx="317.437" cy="226.447" r="4"/>
# <circle clip-path="url(#clip2302)" style="fill:#ff0000; stroke:none; fill-opacity:1" cx="317.437" cy="226.447" r="3"/>
# <circle clip-path="url(#clip2302)" style="fill:#000000; stroke:none; fill-opacity:1" cx="379.437" cy="202.747" r="4"/>
# <circle clip-path="url(#clip2302)" style="fill:#ff0000; stroke:none; fill-opacity:1" cx="379.437" cy="202.747" r="3"/>
# <circle clip-path="url(#clip2302)" style="fill:#000000; stroke:none; fill-opacity:1" cx="441.436" cy="179.606" r="4"/>
# <circle clip-path="url(#clip2302)" style="fill:#ff0000; stroke:none; fill-opacity:1" cx="441.436" cy="179.606" r="3"/>
# <circle c

# %% [markdown]
# **(d)** What conclusions do you draw from the difference between the two curves?

# %% [markdown]
# Polynomial fits can be very sensitive to the input data, especially when extrapolating outside the range of the input data.
