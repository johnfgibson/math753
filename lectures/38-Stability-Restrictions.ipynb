# %% [markdown]
# # Stability restrictions and stiff ODEs

# %%
include("odemethods.jl")
using Plots

# %% [markdown]
# ### Forward Euler on a nonstiff ODE
#
# The ODE $x=-ax$ for $a=1$ and $y(0) = 1$ has explicit solution $x = e^{-t}$.
#
# The stability restriction for Forward Euler on this problem is $\Delta t < 2/a = 2$, so we can take pretty large time steps and still get a stable solution.

# %%
function f_nonstiff(t,x)
    x′ = -x
end

# set initial condition and integration interval
x₀ = [1]
t₀ = 0.0
t₁ = 3.0

# true solution 
t = linspace(t₀, t₁, 100)
x = exp.(-t);

# %%
Δt = 0.32

# compute numerical solutions
tn, xn = forwardEuler(f_nonstiff, y₀, Δt, t₀, t₁)


plot(t, x,    color="black",  label="true solution", legend=:topright)
plot!(tn, xn[:,1], color="red", marker=:circ, label="numerical solution")
plot!(xlabel="t", ylabel="x(t)", title="nonstiff ODE")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3400)" points="
# 54.5598,360.065 580.315,360.065 580.315,31.4961 54.5598,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="54" y="31" width="527" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   69.4396,355.137 69.4396,36.4246
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   234.771,355.137 234.771,36.4246
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   400.103,355.137 400.103,36.4246
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   565.435,355.137 565.435,36.4246
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4461,359.045 572.429,359.045
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4461,279.482 572.429,279.482
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4461,199.92 572.429,199.92
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4461,120.358 572.429,120.358
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   62.4461,40.7952 572.429,40.7952
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,360.065 54.5598,31.4961
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   69.4396,360.065 69.4396,355.137
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   234.771,360.065 234.771,355.137
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   400.103,360.065 400.103,355.137
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   565.435,360.065 565.435,355.137
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,359.045 62.4461,359.045
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,279.482 62.4461,279.482
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,199.92 62.4461,199.92
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,120.358 62.4461,120.358
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,40.7952 62.4461,40.7952
#   "/>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 69.4396, 373.865)" x="69.4396" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 234.771, 373.865)" x="234.771" y="373.865">1</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 400.103, 373.865)" x="400.103" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 565.435, 373.865)" x="565.435" y="373.865">3</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598, 363.545)" x="48.5598" y="363.545">0.00</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598, 283.982)" x="48.5598" y="283.982">0.25</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598, 204.42)" x="48.5598" y="204.42">0.50</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598, 124.858)" x="48.5598" y="124.858">0.75</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598, 45.2952)" x="48.5598" y="45.2952">1.00</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 317.437, 18)" x="317.437" y="18">nonstiff ODE</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 317.437, 397.6)" x="317.437" y="397.6">t</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">x(t)</text>
# </g>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   69.4396,40.7952 74.4497,50.2945
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   74.4497,50.2945 79.4597,59.5102
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   79.4597,59.5102 84.4698,68.4508
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   84.4698,68.4508 89.4799,77.1246
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   89.4799,77.1246 94.4899,85.5395
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   94.4899,85.5395 99.5,93.7032
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   99.5,93.7032 104.51,101.623
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   104.51,101.623 109.52,109.307
#   "/>

# %% [markdown]
# ## Forward Euler on a stiff ODE
#
# The IVP
#
# \begin{equation*}
# x'' + 101 x' + 100 x = 0
# \end{equation*}
#
# with initial condition $x(0) = 1, x'(0) = 0$ has explicit solution
#
#
# \begin{equation*}
# x(t) = -\frac{1}{99} e^{-100t} + \frac{100}{99} e^{-t}
# \end{equation*}
#
# Not that the first term of this solution starts very small and drops to zero very rapidly. And the coefficient of the second term is very nearly 1. So in fact, this solution $x(t)$ is very nearly equal to the solution of the nonstiff problem above!
#
# \begin{equation*}
# x(t) \approx  e^{-t}
# \end{equation*}
#
# Since the solutions of the two problems are essentially the same, you might think we could use the same numerical solution method with the same time-stepping interval. But we can't!
#
# To see this, first translate the second-order ODE in $x$ to a 2d system of first order ODEs in $y = (y_1, y_2) = (x, x')$. The ODE on $y$ is
#
# \begin{equation*}
# y' = Ay
# \end{equation*}
#
# where
#
# \begin{equation*}
# A = \left[\begin{array}{cc} 0 & 1 \\ -100 & -101 \end{array}\right]
# \end{equation*}
#
# with initial conditions $(y_1, y_2) = (1, 0)$.

# %%
function f_stiff(t,y)
    y′ = [0 1 ; -100 -101]*y
end

# set initial condition and integration interval
y₀ = [1, 0]
t₀ = 0.0
t₁ = 3.0

# true solution x(t)
t = linspace(t₀, t₁, 100)
x = -1/99*exp.(-100t) + 100/99*exp.(-t);

# %%
Δt = 0.001

# compute numerical solution
tn, yn = forwardEuler(f_stiff, y₀, Δt, t₀, t₁)

# extract x = y₁
xn = yn[:,1] 

plot(t, x,    color="black",  label="true solution", legend=:topleft)
plot!(tn,xn, color="red", label="numerical solution")
plot!(xlabel="t", ylabel="x(t)", title="stiff ODE")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6800)" points="
# 47.9701,360.065 580.315,360.065 580.315,31.4961 47.9701,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="47" y="31" width="533" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.9701,355.137 47.9701,36.4246
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   225.418,355.137 225.418,36.4246
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   402.867,355.137 402.867,36.4246
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,355.137 580.315,36.4246
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.9553,308.249 572.33,308.249
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.9553,239.06 572.33,239.06
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.9553,169.872 572.33,169.872
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.9553,100.684 572.33,100.684
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.9553,31.4961 572.33,31.4961
#   "/>
# <polyline clip-path="url(#clip6800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip6800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,360.065 47.9701,31.4961
#   "/>
# <polyline clip-path="url(#clip6800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,360.065 47.9701,355.137
#   "/>
# <polyline clip-path="url(#clip6800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   225.418,360.065 225.418,355.137
#   "/>
# <polyline clip-path="url(#clip6800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   402.867,360.065 402.867,355.137
#   "/>
# <polyline clip-path="url(#clip6800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,360.065 580.315,355.137
#   "/>
# <polyline clip-path="url(#clip6800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,308.249 55.9553,308.249
#   "/>
# <polyline clip-path="url(#clip6800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,239.06 55.9553,239.06
#   "/>
# <polyline clip-path="url(#clip6800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,169.872 55.9553,169.872
#   "/>
# <polyline clip-path="url(#clip6800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,100.684 55.9553,100.684
#   "/>
# <polyline clip-path="url(#clip6800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,31.4961 55.9553,31.4961
#   "/>
# <g clip-path="url(#clip6800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 47.9701, 373.865)" x="47.9701" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip6800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 225.418, 373.865)" x="225.418" y="373.865">1</text>
# </g>
# <g clip-path="url(#clip6800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 402.867, 373.865)" x="402.867" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip6800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 373.865)" x="580.315" y="373.865">3</text>
# </g>
# <g clip-path="url(#clip6800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 41.9701, 312.749)" x="41.9701" y="312.749">0.2</text>
# </g>
# <g clip-path="url(#clip6800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 41.9701, 243.56)" x="41.9701" y="243.56">0.4</text>
# </g>
# <g clip-path="url(#clip6800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 41.9701, 174.372)" x="41.9701" y="174.372">0.6</text>
# </g>
# <g clip-path="url(#clip6800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 41.9701, 105.184)" x="41.9701" y="105.184">0.8</text>
# </g>
# <g clip-path="url(#clip6800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 41.9701, 35.9961)" x="41.9701" y="35.9961">1.0</text>
# </g>
# <g clip-path="url(#clip6800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 314.143, 18)" x="314.143" y="18">stiff ODE</text>
# </g>
# <g clip-path="url(#clip6800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 314.143, 397.6)" x="314.143" y="397.6">t</text>
# </g>
# <g clip-path="url(#clip6800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">x(t)</text>
# </g>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,31.4961 53.3474,38.6006
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   53.3474,38.6006 58.7246,48.5588
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   58.7246,48.5588 64.1018,58.3678
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   64.1018,58.3678 69.479,67.8911
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   69.479,67.8911 74.8562,77.1306
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   74.8562,77.1306 80.2335,86.0943
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   80.2335,86.0943 85.6107,94.7904
#   "/>
# <polyline clip-path="url(#clip6802)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   85.6107,94.7904 90.9879,103.227
#   "/>
# <polyl
