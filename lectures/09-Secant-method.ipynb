# %% [markdown]
# # Secant method
#
# The secant method fall between bisection and Newton methods as a way to solve 1d nonlinear equations $f(x)=0$. The idea is best explained with a picture.

# %%
using Plots
gr()

x = linspace(0,4)
f(x) = x.^2 - 4

a = 1
b = 3
fa = f(a)
fb = f(b)

c = a - fa*(b - a)/(fb - fa)

δ = 1 # a small displacement for ploting labels

plot(x, f(x), color="blue",  linestyle=:solid, label="f(x)", linewidth=2)
plot!(x, 0*x, color="black", linestyle=:solid, label="")
plot!([a, b], [fa, fb], color="blue", linestyle=:dash, label="secant")

scatter!([a, b],    [fa, fb],  marker=:circ, color="blue",  label="")
scatter!([a, b, c], [0, 0, 0], marker=:circ, color="black", label="")

annotate!(a, δ, text("a"))
annotate!(b, δ, text("b"))
annotate!(c, δ, text("c"))
annotate!(a, f(a)-δ, text("f(a)"))
annotate!(b, f(b)+2δ, text("f(b)"))
plot!(xlabel="x", ylabel="y", ylims=(-6, 15))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 45.0072,360.065 580.315,360.065 580.315,11.811 45.0072,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="45" y="11" width="536" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   60.1574,354.842 60.1574,17.0348
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   186.409,354.842 186.409,17.0348
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   312.661,354.842 312.661,17.0348
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   438.913,354.842 438.913,17.0348
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   565.165,354.842 565.165,17.0348
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,360.065 572.285,360.065
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,310.315 572.285,310.315
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,260.564 572.285,260.564
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,210.814 572.285,210.814
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,161.063 572.285,161.063
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,111.312 572.285,111.312
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,61.5617 572.285,61.5617
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.0368,11.811 572.285,11.811
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.1574,360.065 60.1574,354.842
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   186.409,360.065 186.409,354.842
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   312.661,360.065 312.661,354.842
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   438.913,360.065 438.913,354.842
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   565.165,360.065 565.165,354.842
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,360.065 45.0072,11.811
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,360.065 53.0368,360.065
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,310.315 53.0368,310.315
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,260.564 53.0368,260.564
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,210.814 53.0368,210.814
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,161.063 53.0368,161.063
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,111.312 53.0368,111.312
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,61.5617 53.0368,61.5617
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.0072,11.811 53.0368,11.811
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 60.1574, 373.865)" x="60.1574" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 186.409, 373.865)" x="186.409" y="373.865">1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 312.661, 373.865)" x="312.661" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 438.913, 373.865)" x="438.913" y="373.865">3</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 565.165, 373.865)" x="565.165" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 364.565)" x="39.0072" y="364.565">-6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 314.815)" x="39.0072" y="314.815">-3</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 265.064)" x="39.0072" y="265.064">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 215.314)" x="39.0072" y="215.314">3</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 165.563)" x="39.0072" y="165.563">6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 115.812)" x="39.0072" y="115.812">9</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.0072, 66.0617)" x="39.0072" y="66.0617">12</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; fo

# %% [markdown]
# Like bisection, the secant method begins with a bracket. Only instead of taking the midpoint as the next iterate, you draw the secant to the curve (the line that connects the two points $(a, f(a))$ and $(b, f(b))$), and you choose the point $c$ where the secant crosses the $y$ axis.
#
# Let's derive a formula for the value of $c$. Think of the secant line $\hat{f}(x)$ as a linear approximation to $f(x)$ that starts at point $(a, f(a))$ and moves upward from there with slope $(f(b) - f(a))/(b-a)$. The formula for such a line is
#
# \begin{equation*}
# \hat{f}(x) = f(a) + (x-a) \, \frac{f(b) - f(a)}{b-a}
# \end{equation*}
#
# At the intersection point with $y=0$ we have $\hat{f}(c) = 0$. Plug that in to the above
#
# \begin{equation*}
# 0 = f(a) + (c-a) \, \frac{f(b) - f(a)}{b-a}
# \end{equation*}
#
# and solve for $c$ to get
#
# \begin{equation*}
# c = a - f(a) \, \frac{b-a}{f(b) - f(a)}
# \end{equation*}
#
# Unlike the bisection algorithm, $c$ is not guaranteed to lie between $a$ and $b$, so we need some other way of choosing which of $a$ and $b$ to replace for the iteration. Standard practice is to replace whichever of $|f(a)|$ and $|f(b)|$ is larger.

# %% [markdown]
# ## Pseudocode for secant method
#
# ```
# secantsearch(f, a, b)
#     start with a,b preferably bracketing a root of f(x)
#
#     while approximate solution is still not good enough
#
#        compute c = a - f(a) (b-a)/(f(b) - f(a))
#
#        if |f(c)| is not smaller than the lesser of |f(a)| and |f(b)|
#           then algorithm isn't converging, so exit
#        end
#
#        if |f(a)| > |f(b)|
#           let a = c
#        else
#           let b = c
#        end
#
#     end
#
#     return c
# end
# ```
